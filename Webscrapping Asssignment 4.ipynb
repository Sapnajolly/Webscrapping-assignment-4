# %% [markdown]
# # Webscrapping Assignment 4

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\ricky riddhi\anaconda3\lib\site-packages (4.1.3)
# Requirement already satisfied: trio~=0.17 in c:\users\ricky riddhi\anaconda3\lib\site-packages (from selenium) (0.20.0)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in c:\users\ricky riddhi\anaconda3\lib\site-packages (from selenium) (1.26.4)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\ricky riddhi\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\ricky riddhi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (20.3.0)
# Requirement already satisfied: idna in c:\users\ricky riddhi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: sniffio in c:\users\ricky riddhi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: outcome in c:\users\ricky riddhi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\ricky riddhi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: cffi>=1.14 in c:\users\ricky riddhi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.5)
# Requirement already satisfied: sortedcontainers in c:\users\ricky riddhi\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.3.0)
# Requirement already satisfied: pycparser in c:\users\ricky riddhi\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: wsproto>=0.14 in c:\users\ricky riddhi\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.1.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\ricky riddhi\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\ricky riddhi\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (20.0.1)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\ricky riddhi\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (3.4.7)
# Requirement already satisfied: certifi in c:\users\ricky riddhi\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (2020.12.5)
# Requirement already satisfied: six>=1.5.2 in c:\users\ricky riddhi\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure,socks]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\ricky riddhi\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)

# %%
#Import all libraries
import selenium
from selenium import webdriver
import pandas as pd
import warnings
import requests

# importing regex
import re
from selenium import webdriver

# Importing required Exceptions
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait

# %%
driver = webdriver.Chrome(r'C:\Users\Ricky Riddhi\Downloads\chromedriver_win32 (1)\chromedriver.exe')
# Out:
# <ipython-input-31-c09e4a724869>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\Ricky Riddhi\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# %% [markdown]
# Question 1- Scrape the details of most viewed videos on YouTube from Wikipedia.
#
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
#
# You need to find following details:
#
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
#Get webpage
url = 'https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)

# %%
#creating empty list
Rank=[]
Name=[]
Artist=[]
Upload_date=[]
Views=[]

# %%
#Scraping data of rank details
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[1]")[:30]:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('-')
        

#Scraping data of video names
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[2]")[:30]:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('-')

#Scraping data of artist name
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[3]")[:30]:
        Artist.append(i.text)
except NoSuchElementException:        
    Artist.append('-')

#Scraping data of upload dates
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[5]")[:30]:
        Upload_date.append(i.text)
except NoSuchElementException:        
    Upload_date.append('-')

#Scraping data of views
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[4]")[:30]:
        Views.append(i.text)
except NoSuchElementException:
    Views.append('-')
# Out:
# <ipython-input-35-741806494cdf>:3: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[1]")[:30]:
# <ipython-input-35-741806494cdf>:11: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[2]")[:30]:
# <ipython-input-35-741806494cdf>:18: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[3]")[:30]:
# <ipython-input-35-741806494cdf>:25: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[5]")[:30]:
# <ipython-input-35-741806494cdf>:32: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[4]")[:30]:

# %%
#DATA FRAME
Youtube=pd.DataFrame({})
Youtube['Rank'] = Rank
Youtube['Name'] = Name
Youtube['Artist'] = Artist
Youtube['Uploaded Date'] = Upload_date
Youtube['Views'] = Views

# %%
#Printing data frame
Youtube
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.                "Phonics Song with Two Words"[21]
# 7    8.  "Learning Colors – Colorful Eggs on a Farm"[22]
# 8    9.                                "Uptown Funk"[23]
# 9   10.   "Masha and the Bear – Recipe for Disaster"[24]
# 10  11.                              "Gangnam Style"[25]
# 11  12.                          "Wheels on the Bus"[30]
# 12  13.                             "Dame Tu Cosita"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# 15  16.                             "Counting Stars"[34]
# 16  17.                                      "Sorry"[35]
# 17  18.                          "Thinking Out Loud"[36]
# 18  19.                                     "Axel F"[37]
# 19  20.                             "Girls Like You"[38]
# 20  21.                                      "Faded"[39]
# 21  22.                                 "Dark Horse"[40]
# 22  23.                                 "Let Her Go"[41]
# 23  24.                        "Baa Baa Black Sheep"[42]
# 24  25.                                   "Bailando"[43]
# 25  26.                                    "Lean On"[44]
# 26  27.                               "Shake It Off"[45]
# 27  28.                                    "Perfect"[46]
# 28  29.           "Waka Waka (This Time for Africa)"[47]
# 29  30.                                   "Mi Gente"[48]
#
#                                          Artist      Uploaded Date  Views
# 0   Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016  10.53
# 1                                    Luis Fonsi   January 12, 2017   7.82
# 2                                   LooLoo Kids    October 8, 2016   6.31
# 3                                    Ed Sheeran   January 30, 2017   5.69
# 4                                   Wiz Khalifa      April 6, 2015   5.48
# 5                    Cocomelon – Nursery Rhymes        May 2, 2018   5.27
# 6                                     ChuChu TV      March 6, 2014   4.58
# 7                                   Miroshka TV  February 27, 2018   4.56
# 8                                   Mark Ronson  November 19, 2014   4.54
# 9                                    Get Movies   January 31, 2012   4.49
# 10                                          Psy      July 15, 2012   4.40
# 11                   Cocomelon – Nursery Rhymes       May 24, 2018   3.96
# 12                                    El Chombo      April 5, 2018   3.92
# 13                                     Maroon 5   January 14, 2015   3.68
# 14                                   Katy Perry  September 5, 2013   3.56
# 15                                  OneRepublic       May 31, 2013   3.56
# 16                                Justin Bieber   October 22, 2015   3.54
# 17                                   Ed Sheeran    October 7, 2014   3.44
# 18                                   Crazy Frog      June 16, 2009   3.32
# 19                                     Maroon 5       May 31, 2018   3.28
# 20                                  Alan Walker   December 3, 2015   3.27
# 21                                   Katy Perry  February 20, 2014   3.26
# 22                                    Passenger      July 25, 2012   3.21
# 23                   Cocomelon – Nursery Rhymes      June 25, 2018   3.21
# 24                             Enrique Iglesias     April 11, 2014   3.19
# 25                                  Major Lazer     March 22, 2015   3.19
# 26                                 Taylor Swift    August 18, 2014   3.16
# 27                                   Ed Sheeran   November 9, 2017   3.14
# 28                                      Shakira       June 4, 2010   3.12
# 29                                     J Balvin      June 29, 2017   3.07

# %% [markdown]
# Question 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1
# st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
#Import all libraries
import selenium
from selenium import webdriver
import pandas as pd
import warnings
import requests
import time

# importing regex
import re
from selenium import webdriver

# Importing required Exceptions
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait

# %%
driver = webdriver.Chrome(r'C:\Users\Ricky Riddhi\Downloads\chromedriver_win32 (1)\chromedriver.exe')
# Out:
# <ipython-input-85-c09e4a724869>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\Ricky Riddhi\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# %%
# Getting the webpage of mentioned url 
url = "https://www.bcci.tv/."
driver.get(url)

# %%
driver.find_element_by_xpath("//button[@class='cookie__accept btn btn-primary']").click()
# Out:
# <ipython-input-87-fa9e1c06cf7e>:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath("//button[@class='cookie__accept btn btn-primary']").click()

# %%
#Getting url for international fixture and clicking on it
driver.find_element_by_xpath("//li[@class='nav-item ml-0'][1]/a").click()
# Out:
# <ipython-input-88-91290718ff21>:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath("//li[@class='nav-item ml-0'][1]/a").click()

# %%
#Getting International Fixtures
driver.find_element_by_xpath("//div[@class='customSelecBox']").click()
# Out:
# <ipython-input-94-63fb0bdcf250>:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath("//div[@class='customSelecBox']").click()

# %%
#Searching for India
search=driver.find_element_by_xpath("//div[@class='cSBListSearch']/input")
time.sleep(5)
search.send_keys('India')
# Out:
# <ipython-input-95-0503df9a92ab>:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   search=driver.find_element_by_xpath("//div[@class='cSBListSearch']/input")

# %%
#Creating empty list
Match_title=[]
ODI=[]
Place=[]
Date=[]
Time=[]

# %%
#getting the data scrapped for Match_title
try:
    for i in driver.find_elements_by_xpath("//span[@class='ng-binding']"):
        Match_title.append(i.text)
except NoSuchElementException:
    Match_title.append('-')
#len(Match_title)

#getting the data scrapped for ODI
try:
    for i in driver.find_elements_by_xpath("//div[@class='fix-place ng-binding ng-scope']"):
        ODI.append(i.text.split('-')[0])
except NoSuchElementException:
    ODI.append('-')
    
#getting the scrapped data for Place

try:
    for i in driver.find_elements_by_xpath("//div[@class='fix-place ng-binding ng-scope']"):
        Place.append(i.text.split('-')[-1])
except NoSuchElementException:
    Place.append('-')
    
#getting the scrapped data for date

try:
    for i in driver.find_elements_by_xpath("//h5[@class='ng-binding']"):
        Date.append(i.text)
except NoSuchElementException:
    Date.append('-')
#Date
# Out:
# <ipython-input-97-008554e9dac0>:3: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//span[@class='ng-binding']"):
# <ipython-input-97-008554e9dac0>:11: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//div[@class='fix-place ng-binding ng-scope']"):
# <ipython-input-97-008554e9dac0>:19: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//div[@class='fix-place ng-binding ng-scope']"):
# <ipython-input-97-008554e9dac0>:27: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//h5[@class='ng-binding']"):

# %%
#getting the scrapped data for time

try:
    for i in driver.find_elements_by_xpath("//h5[@class='text-right ng-binding']"):
        Time.append(i.text)
except NoSuchElementException:
    Date.append('-')
# Out:
# <ipython-input-98-2e2be2ca4a57>:4: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//h5[@class='text-right ng-binding']"):

# %%
data=list(zip(ODI, Match_title,Place, Date, Time))

# %%
df=pd.DataFrame(data,columns=['ODI','Match_Series','Place','Date','Time'])
df
# Out:
#          ODI                                Match_Series  \
# 0  1st T20I   SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 1  2nd T20I   SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 2  3rd T20I   SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 3  4th T20I   SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 4  5th T20I   SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
#
#                                              Place         Date         Time
# 0                      Arun Jaitley Stadium, Delhi   9 JUN 2022  7:30 PM IST
# 1                        Barabati Stadium, Cuttack  12 JUN 2022  7:30 PM IST
# 2              VDCA Cricket Stadium, Visakhapatnam  14 JUN 2022  7:30 PM IST
# 3   Saurashtra Cricket Association Stadium, Rajkot  17 JUN 2022  7:30 PM IST
# 4                 M Chinnaswamy Stadium, Bengaluru  19 JUN 2022  7:30 PM IST

# %% [markdown]
# Question 3 Scrape the details of selenium exception from guru99.com.
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
driver = webdriver.Chrome(r'C:\Users\Ricky Riddhi\Downloads\chromedriver_win32 (1)\chromedriver.exe')
# Out:
# <ipython-input-116-c09e4a724869>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\Ricky Riddhi\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# %%
# Getting the webpage of mentioned url 
url = "https://www.guru99.com"
driver.get(url)

# %%
#Going to search bar and searching for selenium exception
search_bar = driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[1]/div/table/tbody/tr/td[1]/input")
search_bar.send_keys("selenium exception handling")
ser_but = driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[2]/button").click()
time.sleep(5)
# Out:
# <ipython-input-120-8d0eb513980b>:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   search_bar = driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[1]/div/table/tbody/tr/td[1]/input")
# <ipython-input-120-8d0eb513980b>:4: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   ser_but = driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[2]/button").click()

# %%
#Url of selenium exception handling page
urls = driver.find_element_by_xpath("//div[@class='gsc-expansionArea']//div//a")
page_url = urls.get_attribute("href")

driver.get(page_url)
time.sleep(5)

#Scraping data of names of exceptions
Name = []
for i in driver.find_elements_by_xpath("//table[@class='table table-striped']//tr//td[1]")[1:]:
    Name.append(i.text)
    
#Scraping data of descriptions of exceptions  
Description = []
for i in driver.find_elements_by_xpath("//table[@class='table table-striped']//tr//td[2]")[1:]:
    Description.append(i.text)
# Out:
# <ipython-input-121-35b49e587761>:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   urls = driver.find_element_by_xpath("//div[@class='gsc-expansionArea']//div//a")
# <ipython-input-121-35b49e587761>:10: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//table[@class='table table-striped']//tr//td[1]")[1:]:
# <ipython-input-121-35b49e587761>:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//table[@class='table table-striped']//tr//td[2]")[1:]:

# %%
#DATA FRAMEING
Guru99=pd.DataFrame({})
Guru99['Name of Exception'] = Name
Guru99['Description of Exception'] = Description

# %%
Guru99
# Out:
#                       Name of Exception  \
# 0         ElementNotSelectableException
# 1                NoSuchElementException
# 2                  NoSuchFrameException
# 3               NoAlertPresentException
# 4                 NoSuchWindowException
# 5        StaleElementReferenceException
# 6              SessionNotFoundException
# 7                      TimeoutException
# 8                    WebDriverException
# 9             ConnectionClosedException
# 10     ElementClickInterceptedException
# 11      ElementNotInteractableException
# 12             ErrorInResponseException
# 13  ErrorHandler.UnknownServerException
# 14         ImeActivationFailedException
# 15             ImeNotAvailableException
# 16         InsecureCertificateException
# 17             InvalidArgumentException
# 18         InvalidCookieDomainException
# 19          InvalidCoordinatesException
# 20          InvalidElementStateExceptio
# 21            InvalidSessionIdException
# 22       InvalidSwitchToTargetException
# 23                  JavascriptException
# 24                        JsonException
# 25             NoSuchAttributeException
# 26       MoveTargetOutOfBoundsException
# 27               NoSuchContextException
# 28                NoSuchCookieException
# 29                    NotFoundException
# 30          RemoteDriverServerException
# 31                  ScreenshotException
# 32           SessionNotCreatedException
# 33           UnableToSetCookieException
# 34           UnexpectedTagNameException
# 35              UnhandledAlertException
# 36      UnexpectedAlertPresentException
# 37               UnknownMethodException
# 38          UnreachableBrowserException
# 39          UnsupportedCommandException
#
#                              Description of Exception
# 0   This Selenium exception occurs when an element...
# 1   This Exception occurs if an element could not ...
# 2   This Exception occurs if the frame target to b...
# 3   This Exception occurs when you switch to no pr...
# 4   This Exception occurs if the window target to ...
# 5   This Selenium exception occurs happens when th...
# 6   The WebDriver is acting after you quit the bro...
# 7   Thrown when there is not enough time for a com...
# 8   This Exception takes place when the WebDriver ...
# 9   This type of Exception takes place when there ...
# 10  The command may not be completed as the elemen...
# 11  This Selenium exception is thrown when any ele...
# 12  This happens while interacting with the Firefo...
# 13  Exception is used as a placeholder in case if ...
# 14  This expectation will occur when IME engine ac...
# 15    It takes place when IME support is unavailable.
# 16  Navigation made the user agent to hit a certif...
# 17  It occurs when an argument does not belong to ...
# 18  This happens when you try to add a cookie unde...
# 19  This type of Exception matches an interacting ...
# 20  It occurs when command can’t be finished when ...
# 21  This Exception took place when the given sessi...
# 22  This occurs when the frame or window target to...
# 23  This issue occurs while executing JavaScript g...
# 24  It occurs when you afford to get the session w...
# 25  This kind of Exception occurs when the attribu...
# 26  It takes place if the target provided to the A...
# 27           ContextAware does mobile device testing.
# 28  This Exception occurs when no cookie matching ...
# 29  This Exception is a subclass of WebDriverExcep...
# 30  This Selenium exception is thrown when the ser...
# 31            It is not possible to capture a screen.
# 32  It happens when a new session could not be suc...
# 33  This occurs if a driver is unable to set a coo...
# 34  Happens if a support class did not get a web e...
# 35  This expectation occurs when there is an alert...
# 36  It occurs when there is the appearance of an u...
# 37  This Exception happens when the requested comm...
# 38  This Exception occurs only when the browser is...
# 39  This occurs when remote WebDriver does n’t sen...

# %% [markdown]
# 4.Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
#
# You have to find following details:
#
# A) Rank
#
# B) State
#
# C) GSDP
#
# D) GSDP
#
# E) Share
#
# F) GDP($ billion)
#
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
driver = webdriver.Chrome(r'C:\Users\Ricky Riddhi\Downloads\chromedriver_win32 (1)\chromedriver.exe')
# Out:
# <ipython-input-125-c09e4a724869>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\Ricky Riddhi\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# %%
# Getting the webpage of mentioned url 
url = "http://statisticstimes.com/"
driver.get(url)

# %%
#Clicking on economy section
economy = driver.find_element_by_xpath("//div[@class='navbar']//div[2]//button").click()

urls = driver.find_element_by_xpath("//div[@class='dropdown-content']//a[3]")
ineco_page = urls.get_attribute("href")
#Going to indian economy page
driver.get(ineco_page)  
time.sleep(5)
# Out:
# <ipython-input-127-63064a947fa7>:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   economy = driver.find_element_by_xpath("//div[@class='navbar']//div[2]//button").click()
# <ipython-input-127-63064a947fa7>:4: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   urls = driver.find_element_by_xpath("//div[@class='dropdown-content']//a[3]")

# %%
#Creating empty list
Rank = []
State = []
GSDP_1 = []
GSDP_2 = []
Share = []
GDP = []

# %%
#get the url of page containing GDP of indian states
sta_GDP = driver.find_element_by_xpath("//ul[@style='list-style-type:none;margin-left:20px;']/li/a")
GDP_url = sta_GDP.get_attribute("href")

driver.get(GDP_url)
time.sleep(6)


#Scraping data of rank
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[1]"):
    Rank.append(i.text)

    
#Scraping data of state name
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[2]"):
    State.append(i.text)

    
# Scraping data of GSDP at current price (19-20)
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[3]"):
    GSDP_1.append(i.text)

    
#Scraping data of GSDP at current price (18-19)
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[4]"):
    GSDP_2.append(i.text)

    
#Scraping data of Share(18-19)
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[5]"):
    Share.append(i.text)

    
#Scraping data of GDP($ billion)
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[6]"):
    GDP.append(i.text)
# Out:
# <ipython-input-129-f4ada6ee2c6d>:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   sta_GDP = driver.find_element_by_xpath("//ul[@style='list-style-type:none;margin-left:20px;']/li/a")
# <ipython-input-129-f4ada6ee2c6d>:10: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[1]"):
# <ipython-input-129-f4ada6ee2c6d>:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[2]"):
# <ipython-input-129-f4ada6ee2c6d>:20: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[3]"):
# <ipython-input-129-f4ada6ee2c6d>:25: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[4]"):
# <ipython-input-129-f4ada6ee2c6d>:30: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[5]"):
# <ipython-input-129-f4ada6ee2c6d>:35: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[6]"):

# %%
#DataFraming
data=list(zip(Rank,State,GSDP_1,GSDP_2,Share,GDP))

# %%
df=pd.DataFrame(data,columns=['Rank','Indian_State','GSDP(19-20)','GSDP(18-19)','Share','GDP'])
df
# Out:
#    Rank               Indian_State GSDP(19-20) GSDP(18-19)   Share      GDP
# 0     1                Maharashtra           -   2,632,792  13.94%  399.921
# 1     2                 Tamil Nadu   1,845,853   1,630,208   8.63%  247.629
# 2     3              Uttar Pradesh   1,687,818   1,584,764   8.39%  240.726
# 3     4                    Gujarat           -   1,502,899   7.96%  228.290
# 4     5                  Karnataka   1,631,977   1,493,127   7.91%  226.806
# 5     6                West Bengal   1,253,832   1,089,898   5.77%  165.556
# 6     7                  Rajasthan   1,020,989     942,586   4.99%  143.179
# 7     8             Andhra Pradesh     972,782     862,957   4.57%  131.083
# 8     9                  Telangana     969,604     861,031   4.56%  130.791
# 9    10             Madhya Pradesh     906,672     809,592   4.29%  122.977
# 10   11                     Kerala           -     781,653   4.14%  118.733
# 11   12                      Delhi     856,112     774,870   4.10%  117.703
# 12   13                    Haryana     831,610     734,163   3.89%  111.519
# 13   14                      Bihar     611,804     530,363   2.81%   80.562
# 14   15                     Punjab     574,760     526,376   2.79%   79.957
# 15   16                     Odisha     521,275     487,805   2.58%   74.098
# 16   17                      Assam           -     315,881   1.67%   47.982
# 17   18               Chhattisgarh     329,180     304,063   1.61%   46.187
# 18   19                  Jharkhand     328,598     297,204   1.57%   45.145
# 19   20                Uttarakhand           -     245,895   1.30%   37.351
# 20   21            Jammu & Kashmir           -     155,956   0.83%   23.690
# 21   22           Himachal Pradesh     165,472     153,845   0.81%   23.369
# 22   23                        Goa      80,449      73,170   0.39%   11.115
# 23   24                    Tripura      55,984      49,845   0.26%    7.571
# 24   25                 Chandigarh           -      42,114   0.22%    6.397
# 25   26                 Puducherry      38,253      34,433   0.18%    5.230
# 26   27                  Meghalaya      36,572      33,481   0.18%    5.086
# 27   28                     Sikkim      32,496      28,723   0.15%    4.363
# 28   29                    Manipur      31,790      27,870   0.15%    4.233
# 29   30                   Nagaland           -      27,283   0.14%    4.144
# 30   31          Arunachal Pradesh           -      24,603   0.13%    3.737
# 31   32                    Mizoram      26,503      22,287   0.12%    3.385
# 32   33  Andaman & Nicobar Islands           -           -       -        -

# %% [markdown]
# 5. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
#
# You have to find the following details:
#
# A) Repository title
#
# B) Repository description
#
# C) Contributors count
#
# D) Language used
#
# ASSIGNMENT
#
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
driver = webdriver.Chrome(r'C:\Users\Ricky Riddhi\Downloads\chromedriver_win32 (1)\chromedriver.exe')
# Out:
# <ipython-input-136-c09e4a724869>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\Ricky Riddhi\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# %%
#getting the desired webpage.
url='https://github.com/'
driver.get(url)
time.sleep(2)

# %%
#Getting explore button and clicking on it
explore = driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details").click()

#Selecting trending option
trend_url = driver.find_element_by_xpath("/html/body/div[1]/header/div[1]/div[2]/nav/ul/li[4]/details/div[1]/ul[1]/li[3]/a")
urls = trend_url.get_attribute("href")
driver.get(urls)
# Out:
# <ipython-input-138-ea37a0c8e3cf>:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   explore = driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details").click()
# <ipython-input-138-ea37a0c8e3cf>:5: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   trend_url = driver.find_element_by_xpath("/html/body/div[1]/header/div[1]/div[2]/nav/ul/li[4]/details/div[1]/ul[1]/li[3]/a")

# %%
#Creating empty list
URLs = []
repository_title = []
Description = []
Contributors = []
Language = []
lang = []

# %%
#Fetching urls for each repository
repository = driver.find_elements_by_xpath("//h1[@class = 'h3 lh-condensed']//a")
for i in repository:
    URLs.append(i.get_attribute("href"))

    
# Scraping Repository Title data
title = driver.find_elements_by_xpath("//h1[@class = 'h3 lh-condensed']")
for i in title:
    repository_title.append(i.text)

    
# Scraping data from all repository page
for i in URLs:
    driver.get(i)
    time.sleep(3)
    
    
    # Scraping Repository Description data
    try:
        desc = driver.find_element_by_xpath("//p[@class='f4 mt-3']")
        Description.append(desc.text)
    except NoSuchElementException:
        Description.append('-')
        
        
    # Scraping Contributors Count data
    try:
        contributor = driver.find_element_by_xpath("//*[contains(text(),'    Contributors ')]")
        Contributors.append(contributor.text.replace('Contributors',''))
    except NoSuchElementException:
        Contributors.append('-')
        
        
    # Scraping Languages used data
    try:
        for i in driver.find_elements_by_xpath("//span[@class='color-text-primary text-bold mr-1']"):
            lang.append(i.text)
        Language.append(lang)
    except NoSuchElementException:
        Language.append('-')
# Out:
# <ipython-input-141-72ce4e381d41>:2: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   repository = driver.find_elements_by_xpath("//h1[@class = 'h3 lh-condensed']//a")
# <ipython-input-141-72ce4e381d41>:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   title = driver.find_elements_by_xpath("//h1[@class = 'h3 lh-condensed']")

# %%
#DATA FRAMEING
Github=pd.DataFrame({})
Github['Repository title'] = repository_title
Github['Repository description'] = Description
Github['Contributors count'] = Contributors
Github['Language used'] = Language
Github
# Out:
# Empty DataFrame
# Columns: [Repository title, Repository description, Contributors count, Language used]
# Index: []

# %% [markdown]
# 6. Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/
#
# You have to find the following details:
#
# A) Song name
#
# B) Artist name
#
# C) Last week rank
#
# D) Peak rank
#
# E) Weeks on board
#
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver = webdriver.Chrome(r'C:\Users\Ricky Riddhi\Downloads\chromedriver_win32 (1)\chromedriver.exe')
# Out:
# <ipython-input-164-c09e4a724869>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\Ricky Riddhi\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# %%
# Getting the webpage of mentioned url 
url = "https:/www.billboard.com/"
driver.get(url)

# %% [raw]
# driver.find_element_by_xpath("//a[@class='c-link  lrv-a-unstyle-link a-font-primary-bold lrv-u-font-size-28@desktop-xl lrv-u-font-size-18 lrv-u-color-grey:hover u-padding-a-1@desktop-max lrv-u-padding-b-050']").click()

# %%
driver.find_element_by_xpath("//a[@class='c-link  lrv-a-unstyle-link lrv-u-font-size-18@desktop lrv-u-color-grey:hover u-color-brand-secondary:hover@desktop-max u-padding-a-1@desktop-max lrv-u-padding-tb-025 lrv-u-display-block']").click()
# Out:
# <ipython-input-174-5598fdf2ba8e>:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath("//a[@class='c-link  lrv-a-unstyle-link lrv-u-font-size-18@desktop lrv-u-color-grey:hover u-color-brand-secondary:hover@desktop-max u-padding-a-1@desktop-max lrv-u-padding-tb-025 lrv-u-display-block']").click()

# %%
# Creating empty lists
Song_Name = []
Artist_Name = []
Last_week_rank = []
Peak_rank = []
Weeks_on_board = []

# Scraping data of song names
for i in driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']"):
    Song_Name.append(i.text)
    
# Scraping data of artist names
for i in driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']"):
    Artist_Name.append(i.text)
    
# Scraping data of last week ranks
for i in driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']"):
    Last_week_rank.append(i.text)
    
# Scraping data of peak rank
for i in driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']"):
    Peak_rank.append(i.text)
    
# Scraping data of weeks on board
for i in driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']"):
    Weeks_on_board.append(i.text)
    
# Creating dataframe for scraped data
billboard=pd.DataFrame({})
billboard['Name'] = Song_Name
billboard['Artist'] = Artist_Name
billboard['Last week rank'] = Last_week_rank
billboard['Peak rank'] = Peak_rank
billboard['Weeks on board'] = Weeks_on_board
billboard
# Out:
# <ipython-input-175-102c13a023c5>:9: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']"):
# <ipython-input-175-102c13a023c5>:13: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']"):
# <ipython-input-175-102c13a023c5>:17: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']"):
# <ipython-input-175-102c13a023c5>:21: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']"):
# <ipython-input-175-102c13a023c5>:25: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']"):
# Empty DataFrame
# Columns: [Name, Artist, Last week rank, Peak rank, Weeks on board]
# Index: []

# %% [markdown]
# 7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
#
# You have to find the following details:
#
# A) Name
#
# B) Designation
#
# C) Company
#
# D) Skills they hire for
#
# E) Location
#
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and click on search. All this should be done through code

# %%
driver = webdriver.Chrome(r'C:\Users\Ricky Riddhi\Downloads\chromedriver_win32 (1)\chromedriver.exe')
# Out:
# <ipython-input-228-c09e4a724869>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\Ricky Riddhi\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# %%
# Getting the webpage of mentioned url 
url = "https://www.naukri.com/"
driver.get(url)

# %%
#Fetching urls to navigate recruiter page
driver.find_element_by_xpath("//div[@class='mTxt']").click()
# Out:
# <ipython-input-230-86737ff3076c>:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath("//div[@class='mTxt']").click()

# %%
recruiter = driver.find_elements_by_xpath("/html/body/div[1]/div/ul/li[2]/a")
# Out:
# <ipython-input-231-b4df2f168f79>:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   recruiter = driver.find_elements_by_xpath("/html/body/div[1]/div/ul/li[2]/a")

# %%
# Fetching search button, sending keys and clicking on it
search = driver.find_elements_by_xpath("//div[@class='inWrap]']")
search.send_keys("Data science ")           
btn = driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']").click()     
time.sleep(3)
# Out:
# <ipython-input-253-0b3f08dcd251>:2: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   search = driver.find_elements_by_xpath("//div[@class='inWrap]']")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-253-0b3f08dcd251> in <module>
#       1 # Fetching search button, sending keys and clicking on it
#       2 search = driver.find_elements_by_xpath("//div[@class='inWrap]']")
# ----> 3 search.send_keys("Data science ")
#       4 btn = driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']").click()
#       5 time.sleep(3)
#
# AttributeError: 'list' object has no attribute 'send_keys'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-254-8d3bee3d2b74> in <module>
# ----> 1 search.send_keys("Data Science")
#
# AttributeError: 'list' object has no attribute 'send_keys'

# %%
#Creating empty lists
Name = []
Designation = []
Company = []
Skills = []
Location = []

#Scraping data of Names
for i in driver.find_elements_by_xpath("//span[@class='fl ellipsis']"):
    Name.append(i.text)
time.sleep(3)


#Scraping data of Designation
for i in driver.find_elements_by_xpath("//span[@class='ellipsis clr']"):
    Designation.append(i.text)
time.sleep(3)

#Scraping data of company name
for i in driver.find_elements_by_xpath("//div[@class='vcard']//p[1]/a[2]"):
    Company.append(i.text)
time.sleep(3)
    
#scraping data of Skills 
for i in driver.find_elements_by_xpath("//div[@class='hireSec highlightable']"):
    try:
        if i.text == "Not Specified": raise NoSuchElementException
        Skills.append(i.text)
    except NoSuchElementException:
        Skills.append('-')
    time.sleep(3)

#Scraping data of locations
for i in driver.find_elements_by_xpath("//div[@class='vcard']//p[1]//span"):
    Location.append(i.text)
time.sleep(3)

# Creating dataframe for scraped data
Naukri=pd.DataFrame({})
Naukri['Name'] = Name[:50]
Naukri['Designation'] = Designation[:50]
Naukri['Company'] = Company[:50]
Naukri['Skills'] = Skills[:50]
Naukri['Location'] = Location[:50]
Naukri
# Out:
# <ipython-input-255-ee6c0babbbe9>:9: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//span[@class='fl ellipsis']"):
# <ipython-input-255-ee6c0babbbe9>:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//span[@class='ellipsis clr']"):
# <ipython-input-255-ee6c0babbbe9>:20: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//div[@class='vcard']//p[1]/a[2]"):
# <ipython-input-255-ee6c0babbbe9>:25: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//div[@class='hireSec highlightable']"):
# <ipython-input-255-ee6c0babbbe9>:34: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//div[@class='vcard']//p[1]//span"):
# Empty DataFrame
# Columns: [Name, Designation, Company, Skills, Location]
# Index: []

# %% [markdown]
# 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
#
# You have to find the following details:
#
# A) Book name
#
# B) Author name
#
# C) Volumes sold
#
# D) Publisher
#
# E) Genre

# %%
driver = webdriver.Chrome(r'C:\Users\Ricky Riddhi\Downloads\chromedriver_win32 (1)\chromedriver.exe')
# Out:
# <ipython-input-257-c09e4a724869>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\Ricky Riddhi\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# %%
# Getting the webpage of mentioned url 
url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare"
driver.get(url)

# %%
#create an empty lists to store the scraping data
Book_Name=[] 
Author_Name=[] 
Volumes_Sold=[]
Publisher=[] 
Genre=[]

#create a function
book = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[2]')
for i in book:
    Book_Name.append(i.text)
author = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[3]')
for i in author:
    Author_Name.append(i.text)
vol = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[4]')
for i in vol:
    Volumes_Sold.append(i.text)
pub = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[5]')
for i in pub:
    Publisher.append(i.text)
gen = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[6]')
for i in gen:
    Genre.append(i.text)
    
# create the dataframe from the scraped data
Novel=pd.DataFrame({})
Novel['Book Name']=Book_Name
Novel['Author Name']= Author_Name
Novel['Volumes Sold']=Volumes_Sold
Novel['Publisher']=Publisher
Novel['Genre']=Genre
Novel
# Out:
# <ipython-input-259-8c9637d76bdd>:9: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   book = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[2]')
# <ipython-input-259-8c9637d76bdd>:12: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   author = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[3]')
# <ipython-input-259-8c9637d76bdd>:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   vol = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[4]')
# <ipython-input-259-8c9637d76bdd>:18: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   pub = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[5]')
# <ipython-input-259-8c9637d76bdd>:21: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   gen = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[6]')
#                                             Book Name       Author Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes Sold        Publisher                        Genre
# 0     5,094,805       Transworld  Crime, Thriller & Adventure
# 1     4,475,152       Bloomsbury           Children's Fiction
# 2     4,200,654       Bloomsbury           Children's Fiction
# 3     4,179,479       Bloomsbury           Children's Fiction
# 4     3,758,936     Random House              Romance & Sagas
# ..          ...              ...                          ...
# 95      807,311     Random House   General & Literary Fiction
# 96      794,201          Penguin        Food & Drink: General
# 97      792,187  Scholastic Ltd.          Young Adult Fiction
# 98      791,507            Orion           Biography: General
# 99      791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %% [markdown]
# 9. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
#
# You have to find the following details:
#
# A) Name
#
# B) Year span
#
# C) Genre
#
# D) Run time
#
# E) Ratings
#
# F) Votes

# %%
driver = webdriver.Chrome(r'C:\Users\Ricky Riddhi\Downloads\chromedriver_win32 (1)\chromedriver.exe')
# Out:
# <ipython-input-260-c09e4a724869>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\Ricky Riddhi\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# %%
# Getting the webpage of mentioned url 
url = "https://www.imdb.com/list/ls095964455/"
driver.get(url)

# %%
#Creating empty lists.
Name = []
Year_span = []
Genre = []
Run_time = []
Ratings = []
Votes = []

# %%
#Scraping data of Names
for i in driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a"):
    Name.append(i.text)

    
#Scraping data of Year span
for i in driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']"):
    Year_span.append(i.text)

    
#Scraping data of genre
for i in driver.find_elements_by_xpath("//span[@class='genre']"):
    Genre.append(i.text)

    
#Scraping data of Run time
for i in driver.find_elements_by_xpath("//span[@class='runtime']"):
    Run_time.append(i.text)

    
#Scraping data of Ratings
for i in driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']//span[2]"):
    Ratings.append(i.text)

    
#Scraping data of votes
for i in driver.find_elements_by_xpath("//div[@class='lister-item-content']//p[4]/span[2]"):
    Votes.append(i.text)
# Out:
# <ipython-input-263-7eb493ec9d72>:2: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a"):
# <ipython-input-263-7eb493ec9d72>:7: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']"):
# <ipython-input-263-7eb493ec9d72>:12: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//span[@class='genre']"):
# <ipython-input-263-7eb493ec9d72>:17: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//span[@class='runtime']"):
# <ipython-input-263-7eb493ec9d72>:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']//span[2]"):
# <ipython-input-263-7eb493ec9d72>:27: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in driver.find_elements_by_xpath("//div[@class='lister-item-content']//p[4]/span[2]"):

# %%
#DATA FRAMEING
IMDB=pd.DataFrame({})
IMDB['Name'] = Name
IMDB['Year Span'] = Year_span
IMDB['Genre'] = Genre
IMDB['Run Time'] = Run_time
IMDB['Ratings'] = Ratings
IMDB['Votes'] = Votes
IMDB
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  1,981,522
# 1    51 min     8.7    987,228
# 2    44 min     8.2    944,296
# 3    60 min     7.5    282,112
# 4    43 min     7.6    242,009
# ..      ...     ...        ...
# 95   42 min     7.4     48,564
# 96   50 min     7.8     59,197
# 97   42 min     8.1    188,911
# 98   45 min     7.1     40,032
# 99  572 min     8.6    226,490
#
# [100 rows x 6 columns]

# %% [markdown]
# 10. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
#
# You have to find the following details:
#
# A) Dataset name
#
# B) Data type
#
# C) Task
#
# D) Attribute type
#
# E) No of instances
#
# F) No of attribute
#
# G) Year
#
# Note: - from the home page you have to go to the ShowAllDataset page through code

# %%
driver = webdriver.Chrome(r'C:\Users\Ricky Riddhi\Downloads\chromedriver_win32 (1)\chromedriver.exe')
# Out:
# <ipython-input-265-c09e4a724869>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\Ricky Riddhi\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# %%
# Getting the webpage of mentioned url 
url = "https://archive.ics.uci.edu/"
driver.get(url)

# %%
#Finding view all dataset button
view_dataset = driver.find_element_by_xpath("//tbody[1]//tr/td[2]/span[2]/a")    
page_url = view_dataset.get_attribute("href")
driver.get(page_url)
time.sleep(5)

#Getting page urls containing list of all datasets
all_lst = driver.find_element_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[1]/tbody/tr/td[2]/p/a")  
lst_url = all_lst.get_attribute("href")           
driver.get(lst_url)
time.sleep(5)

#fetching url for each dataset
data_url = driver.find_elements_by_xpath("//p[@class='normal']//b/a")    

urls = []     
for i in data_url:
    urls.append(i.get_attribute("href"))
# Out:
# <ipython-input-267-ae1277f57b39>:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   view_dataset = driver.find_element_by_xpath("//tbody[1]//tr/td[2]/span[2]/a")
# <ipython-input-267-ae1277f57b39>:8: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   all_lst = driver.find_element_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[1]/tbody/tr/td[2]/p/a")
# <ipython-input-267-ae1277f57b39>:14: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   data_url = driver.find_elements_by_xpath("//p[@class='normal']//b/a")

# %%
#Creating empty list
Data_name = []
Data_type = []
Task = []
Attr_type = []
Instances = []
n_attributes = []
Year = []

# %%
#Scraping requiredinfo from urls
for i in urls:
    driver.get(i)
    time.sleep(3)
    
    
    #Scraping Dataset name
    try: 
        ds_name = driver.find_element_by_xpath("//span[@class='heading']")
        Data_name.append(ds_name.text)
    except NoSuchElementException:
        Data_name.append('-')
    time.sleep(1)
    
    
    #Scraping data type
    try:
        dtype = driver.find_element_by_xpath("//table[@border='1']//tbody/tr/td[2]")
        if dtype.text == "N/A": raise NoSuchElementException
        Data_type.append(dtype.text)
    except NoSuchElementException:
        Data_type.append('-')
    time.sleep(1)
    
    
    #Scraping Attribute type
    try:
        atype = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[2]")
        if atype.text == "N/A": raise NoSuchElementException
        Attr_type.append(atype.text)
    except NoSuchElementException:
        Attr_type.append('-')
    time.sleep(1)
    
    
    #scraping Task
    try:
        task = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[3]/td[2]")
        if task.text == "N/A": raise NoSuchElementException
        Task.append(task.text)
    except NoSuchElementException:
        Task.append('-')
    time.sleep(1)
    
    
    #Scraping No of instances
    try:
        inst = driver.find_element_by_xpath("//table[@border='1']//tbody/tr/td[4]")
        if inst.text == "N/A": raise NoSuchElementException
        Instances.append(inst.text)
    except NoSuchElementException:
        Instances.append('-')
    time.sleep(1)
    
    
    #Scraping  No of attribute
    try:
        attr = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[4]")
        if attr.text == "N/A": raise NoSuchElementException
        n_attributes.append(attr.text)
    except NoSuchElementException:
        n_attributes.append('-')
    time.sleep(1)
    
    
    #scraping year
    try:
        year = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[6]")
        if year.text == "N/A": raise NoSuchElementException
        Year.append(year.text[:4])
    except NoSuchElementException:
        Year.append('-')
    time.sleep(1)
# Out:
# <ipython-input-269-3565e5e0571e>:9: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   ds_name = driver.find_element_by_xpath("//span[@class='heading']")
# <ipython-input-269-3565e5e0571e>:18: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   dtype = driver.find_element_by_xpath("//table[@border='1']//tbody/tr/td[2]")
# <ipython-input-269-3565e5e0571e>:28: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   atype = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[2]")
# <ipython-input-269-3565e5e0571e>:38: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   task = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[3]/td[2]")
# <ipython-input-269-3565e5e0571e>:48: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   inst = driver.find_element_by_xpath("//table[@border='1']//tbody/tr/td[4]")
# <ipython-input-269-3565e5e0571e>:58: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   attr = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[4]")
# <ipython-input-269-3565e5e0571e>:68: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   year = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[6]")

# %%
UCI=pd.DataFrame({})
UCI['Data Name'] = Data_name
UCI['Data Type'] = Data_type
UCI['Task'] = Task
UCI['Attribute type'] = Attr_type
UCI['No of instance'] = Instances
UCI['No of attributes'] = n_attributes
UCI['Year'] = Year

UCI
